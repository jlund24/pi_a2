# %%
# Out:
# Requirement already satisfied: altair in ./venv/lib/python3.8/site-packages (4.1.0)
# Requirement already satisfied: vega_datasets in ./venv/lib/python3.8/site-packages (0.9.0)
# Requirement already satisfied: numpy in ./venv/lib/python3.8/site-packages (from altair) (1.20.1)
# Requirement already satisfied: jsonschema in ./venv/lib/python3.8/site-packages (from altair) (3.2.0)
# Requirement already satisfied: pandas>=0.18 in ./venv/lib/python3.8/site-packages (from altair) (1.2.2)
# Requirement already satisfied: entrypoints in ./venv/lib/python3.8/site-packages (from altair) (0.3)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.8/site-packages (from altair) (2.11.3)
# Requirement already satisfied: toolz in ./venv/lib/python3.8/site-packages (from altair) (0.11.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in ./venv/lib/python3.8/site-packages (from jsonschema->altair) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in ./venv/lib/python3.8/site-packages (from jsonschema->altair) (1.15.0)
# Requirement already satisfied: setuptools in ./venv/lib/python3.8/site-packages/setuptools-40.8.0-py3.8.egg (from jsonschema->altair) (40.8.0)
# Requirement already satisfied: attrs>=17.4.0 in ./venv/lib/python3.8/site-packages (from jsonschema->altair) (20.3.0)
# Requirement already satisfied: pytz>=2017.3 in ./venv/lib/python3.8/site-packages (from pandas>=0.18->altair) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in ./venv/lib/python3.8/site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in ./venv/lib/python3.8/site-packages (from jinja2->altair) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import altair as alt
from altair import datum
from vega_datasets import data 
import pandas as pd
import datetime

# %%
alt.__version__
# Out:
# '4.1.0'

# %%
def convertRawTimeToName(time_string):
    return datetime.datetime.strptime(time_string, "%H:%M:%S").strftime("%H:%M")

# print(convertRawTimeToName(frequency_data["Segment Name"][0]))

# %%
frequency_data = pd.read_csv("combined_frequency_1.csv", header=0)
frequency_data["Segment Name"] = frequency_data["Segment Name"].transform(convertRawTimeToName)
line_domain = frequency_data["Segment Name"].tolist()
print(frequency_data.head(20))
# Out:
#     Unnamed: 0  Unnamed: 0.1  Type  Segment ID Segment Name  Activity Code  \
# 0            0           0.0  ATUS           0        00:00              1
# 1            1           1.0  ATUS           0        00:00              1
# 2            2           2.0  ATUS           0        00:00              1
# 3            3           3.0  ATUS           0        00:00              1
# 4            4           4.0  ATUS           0        00:00              1
# 5            5           5.0  ATUS           0        00:00              1
# 6            6           6.0  ATUS           0        00:00              1
# 7            7           7.0  ATUS           0        00:00              1
# 8            8           8.0  ATUS           0        00:00              1
# 9            9           9.0  ATUS           0        00:00              1
# 10          10          10.0  ATUS           0        00:00              1
# 11          11          11.0  ATUS           0        00:00              1
# 12          12          12.0  ATUS           0        00:00              1
# 13          13          13.0  ATUS           0        00:00              1
# 14          14          14.0  ATUS           0        00:00              1
# 15          15          15.0  ATUS           0        00:00              1
# 16          16          16.0  ATUS           1        00:15              1
# 17          17          17.0  ATUS           1        00:15              1
# 18          18          18.0  ATUS           1        00:15              1
# 19          19          19.0  ATUS           1        00:15              1
#
#     Activity Name  Entry Count  Activity Count  \
# 0   personal care     0.895048              16
# 1   personal care     0.895048              16
# 2   personal care     0.895048              16
# 3   personal care     0.895048              16
# 4   personal care     0.895048              16
# 5   personal care     0.895048              16
# 6   personal care     0.895048              16
# 7   personal care     0.895048              16
# 8   personal care     0.895048              16
# 9   personal care     0.895048              16
# 10  personal care     0.895048              16
# 11  personal care     0.895048              16
# 12  personal care     0.895048              16
# 13  personal care     0.895048              16
# 14  personal care     0.895048              16
# 15  personal care     0.895048              16
# 16  personal care     0.915254              16
# 17  personal care     0.915254              16
# 18  personal care     0.915254              16
# 19  personal care     0.915254              16
#
#                                      Code     Count
# 0                           personal care  0.895048
# 1      socializing, relaxing, and leisure  0.067385
# 2          work & work related activities  0.013004
# 3                               traveling  0.006830
# 4                    household activities  0.004597
# 5                     eating and drinking  0.003415
# 6                             no response  0.002102
# 7            caring for household members  0.001970
# 8                         telephone calls  0.001576
# 9                               education  0.001182
# 10        caring for nonhousehold members  0.001051
# 11       sports, exercise, and recreation  0.000525
# 12     religious and spiritual activities  0.000525
# 13                   volunteer activities  0.000394
# 14                     consumer purchases  0.000263
# 15  professional & personal care services  0.000131
# 16                          personal care  0.915254
# 17     socializing, relaxing, and leisure  0.055118
# 18         work & work related activities  0.011878
# 19                              traveling  0.004137

# %%
# print(segmented_data.columns)
source = data.seattle_temps.url

time_segment_list = {0: '00:00:00',1: '00:15:00',2: '00:30:00',3: '00:45:00',4: '01:00:00',5: '01:15:00',6: '01:30:00',7: '01:45:00',8: '02:00:00',9: '02:15:00',10: '02:30:00',11: '02:45:00',12: '03:00:00',13: '03:15:00',14: '03:30:00',15: '03:45:00',16: '04:00:00',17: '04:15:00',18: '04:30:00',19: '04:45:00',20: '05:00:00',21: '05:15:00',22: '05:30:00',23: '05:45:00',24: '06:00:00',25: '06:15:00',26: '06:30:00',27: '06:45:00',28: '07:00:00',29: '07:15:00',30: '07:30:00',31: '07:45:00',32: '08:00:00',33: '08:15:00',34: '08:30:00',35: '08:45:00',36: '09:00:00',37: '09:15:00',38: '09:30:00',39: '09:45:00',40: '10:00:00',41: '10:15:00',42: '10:30:00',43: '10:45:00',44: '11:00:00',45: '11:15:00',46: '11:30:00',47: '11:45:00',48: '12:00:00',49: '12:15:00',50: '12:30:00',51: '12:45:00',52: '13:00:00',53: '13:15:00',54: '13:30:00',55: '13:45:00',56: '14:00:00',57: '14:15:00',58: '14:30:00',59: '14:45:00',60: '15:00:00',61: '15:15:00',62: '15:30:00',63: '15:45:00',64: '16:00:00',65: '16:15:00',66: '16:30:00',67: '16:45:00',68: '17:00:00',69: '17:15:00',70: '17:30:00',71: '17:45:00',72: '18:00:00',73: '18:15:00',74: '18:30:00',75: '18:45:00',76: '19:00:00',77: '19:15:00',78: '19:30:00',79: '19:45:00',80: '20:00:00',81: '20:15:00',82: '20:30:00',83: '20:45:00',84: '21:00:00',85: '21:15:00',86: '21:30:00',87: '21:45:00',88: '22:00:00',89: '22:15:00',90: '22:30:00',91: '22:45:00',92: '23:00:00',93: '23:15:00',94: '23:30:00',95: '23:45:00'}

# input_checkbox = alt.binding_checkbox()
# checkbox_selection = alt.selection_single(bind=input_checkbox, name="Days of Week")

multi = alt.selection_multi(on='click', toggle=True)
interval = alt.selection_interval()

color = alt.condition(interval, alt.Color(field="Activity Name", type="nominal", scale=alt.Scale(scheme="inferno")), alt.value('lightgray'))

heatmap = alt.Chart(
     frequency_data,
#     source,
    title="Most Common Activity"
).transform_filter(
    alt.FieldOneOfPredicate(field="Type", oneOf=["ATUS", "Me - Combined", "Me - Weekend", "Me - Workday"])
).mark_rect().encode(
    x=alt.X('Segment Name', title="Time of Day"),
    y=alt.Y('Type', title="Type of Day", band = 0.9, sort=["ATUS", "Me - Combined", "Me - Weekend", "Me - Workday", "Me - Monday", "Me - Tuesday", "Me - Wednesday", "Me - Thursday", "Me - Friday", "Me - Saturday", "Me - Sunday"]),
#     color=alt.Color('Activity Code', scale=alt.Scale(scheme="inferno")),
#     color=alt.condition(interval, alt.Color(field="Activity Code", type="nominal", scale=alt.Scale(scheme="inferno")), alt.value('lightgray')),
    color=color,
    tooltip=[
        alt.Tooltip('Entry Count', title='% Entries'),
        alt.Tooltip('Activity Name', title='Activity')
    ]
).properties(width=1000, height=200
).add_selection(
        interval
    )



bars = alt.Chart(frequency_data,
    title="Activity Proportions"
).transform_filter(
alt.FieldOneOfPredicate(field="Type", oneOf=["ATUS", "Me - Combined", "Me - Weekend", "Me - Workday"])
).transform_filter(
    interval
).mark_bar().encode(
    y=alt.Y(field="Count", aggregate="sum", type="quantitative", stack="normalize"),
    x=alt.X('Type', title="Type of Day", band = 0.9, sort=["ATUS", "Me - Combined", "Me - Weekend", "Me - Workday", "Me - Monday", "Me - Tuesday", "Me - Wednesday", "Me - Thursday", "Me - Friday", "Me - Saturday", "Me - Sunday"]),
    color=alt.Color(field="Code", type="nominal"),
    tooltip=[
        alt.Tooltip('Count', title='Count'),
        alt.Tooltip('Code', title='Activity')
    ],
#     order=alt.Order('sum(sum(Code)):Q', sort='ascending')
).properties(height=500)

line = alt.Chart(frequency_data,
    title="Distinct Activities"
).transform_filter(
alt.FieldOneOfPredicate(field="Type", oneOf=["ATUS", "Me - Combined", "Me - Weekend", "Me - Workday"])
).transform_filter(interval
                 ).mark_line().encode(
    x=alt.X('Segment Name', title="Time of Day", scale=alt.Scale(domain=line_domain)),
    y=alt.Y(field="Activity Count", type="quantitative", scale=alt.Scale(domain=[0,18])),
#     y=alt.Y('Activity Count', title="Type of Day", band = 0.9, sort=["ATUS", "Me - Combined", "Me - Weekend", "Me - Workday", "Me - Monday", "Me - Tuesday", "Me - Wednesday", "Me - Thursday", "Me - Friday", "Me - Saturday", "Me - Sunday"]),
#     color=alt.Color(field="Type", type="nominal"),
    color=alt.condition(interval, alt.Color(field="Type", type="nominal"), alt.value('lightgray')),
    tooltip=[
        alt.Tooltip('Segment Name', title='Time'),
        alt.Tooltip('Type', title='Type')
    ]
).properties(width=1000, height=200)

line = line.add_selection(alt.selection_single())
bars = bars.add_selection(alt.selection_single())

(heatmap & line) | bars
# Out:
# alt.HConcatChart(...)
